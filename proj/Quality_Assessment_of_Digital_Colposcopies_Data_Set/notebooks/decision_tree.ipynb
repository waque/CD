# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sys
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import mutual_info_classif, f_classif, SelectKBest
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, VotingClassifier
from sklearn.naive_bayes import GaussianNB, MultinomialNB, BernoulliNB
from sklearn.feature_selection import SelectKBest
from sklearn.model_selection import train_test_split, cross_val_score, KFold
from sklearn.feature_selection import chi2
from sklearn.preprocessing import Normalizer, StandardScaler
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import cross_val_score, cross_validate
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.metrics import roc_curve, auc
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from sklearn.decomposition import PCA

# %%
green_data = pd.read_csv('../green_consensus.csv')
hinselmann_data = pd.read_csv('../hinselmann_consensus.csv')
schiller_data = pd.read_csv('../schiller_consensus.csv')
experts = ['experts::{}'.format(i) for i in range(5)]

col = pd.concat([green_data, hinselmann_data, schiller_data])
col = col.drop(columns=experts)

X, y = col.drop(columns=['consensus']), col['consensus']
res = {}
i = 0

# %%
min_samples_split = np.arange(2, 25, 2)

# %%
for samples in min_samples_split:
    clf = DecisionTreeClassifier(min_samples_split=samples)
    accuracy = np.mean(cross_val_score(clf, X, y, cv=10))
    roc_auc = np.mean(cross_val_score(clf, X, y, scoring='roc_auc', cv=10))
    res[i] = {'accuracy': accuracy, 'roc_auc': roc_auc, 'min_samples_split': samples, 'transformation': 'baseline'}
    i += 1

# %%
max_features = np.arange(10, 62, 2)

for samples in max_features:
    clf = DecisionTreeClassifier(min_samples_split=23, max_features=samples)
    accuracy = np.mean(cross_val_score(clf, X, y, cv=10))
    roc_auc = np.mean(cross_val_score(clf, X, y, scoring='roc_auc', cv=10))
    res[i] = {'accuracy': accuracy, 'roc_auc': roc_auc, 'max_features': samples, 'transformation': 'baseline'}
    i += 1

# %%
res
# Out:
# {0: {'accuracy': 0.7444809341361065,
#   'roc_auc': 0.6918452380952381,
#   'min_samples_split': 2,
#   'transformation': 'baseline'},
#  1: {'accuracy': 0.7626117496807152,
#   'roc_auc': 0.6507142857142857,
#   'min_samples_split': 4,
#   'transformation': 'baseline'},
#  2: {'accuracy': 0.7272395548257617,
#   'roc_auc': 0.6985289115646258,
#   'min_samples_split': 6,
#   'transformation': 'baseline'},
#  3: {'accuracy': 0.7377257799671593,
#   'roc_auc': 0.6949574829931973,
#   'min_samples_split': 8,
#   'transformation': 'baseline'},
#  4: {'accuracy': 0.712962962962963,
#   'roc_auc': 0.6787499999999999,
#   'min_samples_split': 10,
#   'transformation': 'baseline'},
#  5: {'accuracy': 0.747824302134647,
#   'roc_auc': 0.7055017006802721,
#   'min_samples_split': 12,
#   'transformation': 'baseline'},
#  6: {'accuracy': 0.7407954752782339,
#   'roc_auc': 0.7186649659863945,
#   'min_samples_split': 14,
#   'transformation': 'baseline'},
#  7: {'accuracy': 0.7476920270023719,
#   'roc_auc': 0.7430697278911564,
#   'min_samples_split': 16,
#   'transformation': 'baseline'},
#  8: {'accuracy': 0.7407954752782339,
#   'roc_auc': 0.7091411564625851,
#   'min_samples_split': 18,
#   'transformation': 'baseline'},
#  9: {'accuracy': 0.7441205984309434,
#   'roc_auc': 0.7150085034013605,
#   'min_samples_split': 20,
#   'transformation': 'baseline'},
#  10: {'accuracy': 0.754720853858785,
#   'roc_auc': 0.7129421768707482,
#   'min_samples_split': 22,
#   'transformation': 'baseline'},
#  11: {'accuracy': 0.744376026272578,
#   'roc_auc': 0.7016751700680273,
#   'min_samples_split': 24,
#   'transformation': 'baseline'},
#  12: {'accuracy': 0.7120461594599526,
#   'roc_auc': 0.6769727891156464,
#   'max_features': 10,
#   'transformation': 'baseline'},
#  13: {'accuracy': 0.70069330414158,
#   'roc_auc': 0.6767346938775509,
#   'max_features': 12,
#   'transformation': 'baseline'},
#  14: {'accuracy': 0.7160144134282065,
#   'roc_auc': 0.6886139455782313,
#   'max_features': 14,
#   'transformation': 'baseline'},
#  15: {'accuracy': 0.7346834519248313,
#   'roc_auc': 0.6854081632653061,
#   'max_features': 16,
#   'transformation': 'baseline'},
#  16: {'accuracy': 0.7071930304688925,
#   'roc_auc': 0.6893367346938777,
#   'max_features': 18,
#   'transformation': 'baseline'},
#  17: {'accuracy': 0.681549899653348,
#   'roc_auc': 0.7145408163265305,
#   'max_features': 20,
#   'transformation': 'baseline'},
#  18: {'accuracy': 0.7174055829228243,
#   'roc_auc': 0.7258248299319728,
#   'max_features': 22,
#   'transformation': 'baseline'},
#  19: {'accuracy': 0.6991698595146871,
#   'roc_auc': 0.692236394557823,
#   'max_features': 24,
#   'transformation': 'baseline'},
#  20: {'accuracy': 0.713464696223317,
#   'roc_auc': 0.6735374149659863,
#   'max_features': 26,
#   'transformation': 'baseline'},
#  21: {'accuracy': 0.7208629812078089,
#   'roc_auc': 0.6988860544217687,
#   'max_features': 28,
#   'transformation': 'baseline'},
#  22: {'accuracy': 0.7313400839262908,
#   'roc_auc': 0.7067346938775511,
#   'max_features': 30,
#   'transformation': 'baseline'},
#  23: {'accuracy': 0.7028644407954753,
#   'roc_auc': 0.71078231292517,
#   'max_features': 32,
#   'transformation': 'baseline'},
#  24: {'accuracy': 0.7138432767743111,
#   'roc_auc': 0.656079931972789,
#   'max_features': 34,
#   'transformation': 'baseline'},
#  25: {'accuracy': 0.7614851304506477,
#   'roc_auc': 0.6834353741496599,
#   'max_features': 36,
#   'transformation': 'baseline'},
#  26: {'accuracy': 0.6886927567962051,
#   'roc_auc': 0.7369217687074829,
#   'max_features': 38,
#   'transformation': 'baseline'},
#  27: {'accuracy': 0.7098659003831418,
#   'roc_auc': 0.6628741496598638,
#   'max_features': 40,
#   'transformation': 'baseline'},
#  28: {'accuracy': 0.7407863528553185,
#   'roc_auc': 0.7105952380952381,
#   'max_features': 42,
#   'transformation': 'baseline'},
#  29: {'accuracy': 0.7373471994161649,
#   'roc_auc': 0.7137670068027211,
#   'max_features': 44,
#   'transformation': 'baseline'},
#  30: {'accuracy': 0.7203703703703704,
#   'roc_auc': 0.7175595238095238,
#   'max_features': 46,
#   'transformation': 'baseline'},
#  31: {'accuracy': 0.7059341361065499,
#   'roc_auc': 0.7007738095238095,
#   'max_features': 48,
#   'transformation': 'baseline'},
#  32: {'accuracy': 0.7589354132457581,
#   'roc_auc': 0.718078231292517,
#   'max_features': 50,
#   'transformation': 'baseline'},
#  33: {'accuracy': 0.7335203430031016,
#   'roc_auc': 0.6854336734693878,
#   'max_features': 52,
#   'transformation': 'baseline'},
#  34: {'accuracy': 0.7161649334063128,
#   'roc_auc': 0.7306207482993197,
#   'max_features': 54,
#   'transformation': 'baseline'},
#  35: {'accuracy': 0.7295612114577631,
#   'roc_auc': 0.7009013605442178,
#   'max_features': 56,
#   'transformation': 'baseline'},
#  36: {'accuracy': 0.7332649151614669,
#   'roc_auc': 0.7203826530612245,
#   'max_features': 58,
#   'transformation': 'baseline'},
#  37: {'accuracy': 0.7473134464513775,
#   'roc_auc': 0.7258673469387755,
#   'max_features': 60,
#   'transformation': 'baseline'}}

# %%
balancer = SMOTE(random_state=42)
X, y = balancer.fit_sample(X, y)

# %%
for samples in min_samples_split:
    clf = DecisionTreeClassifier(min_samples_split=samples)
    accuracy = np.mean(cross_val_score(clf, X, y, cv=10))
    roc_auc = np.mean(cross_val_score(clf, X, y, scoring='roc_auc', cv=10))
    res[i] = {'accuracy': accuracy, 'roc_auc': roc_auc, 'min_samples_split': samples, 'transformation': 'balancing'}
    i += 1

# %%
max_features = np.arange(10, 62, 2)

for samples in max_features:
    clf = DecisionTreeClassifier(min_samples_split=23, max_features=samples)
    accuracy = np.mean(cross_val_score(clf, X, y, cv=10))
    roc_auc = np.mean(cross_val_score(clf, X, y, scoring='roc_auc', cv=10))
    res[i] = {'accuracy': accuracy, 'roc_auc': roc_auc, 'max_features': samples, 'transformation': 'balancing'}
    i += 1

# %%
filename = 'dt_results'
measures = pd.DataFrame.from_dict(res, "index")
measures.to_csv('{}.csv'.format(filename), index=False)
