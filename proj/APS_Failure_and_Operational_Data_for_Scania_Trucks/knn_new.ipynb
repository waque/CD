# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sys
sys.path.append('..')
from utils_cd import (
        split_dataset,
        standard_deviation,
        plot_comparison_results,
        impute_values,
        plot_results,
        plot_param_improv,
        plot_results_from_csv,
        aps_classifier_statistics,
        aps_score,
)
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB, MultinomialNB, BernoulliNB
from sklearn.decomposition import PCA
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.preprocessing import Normalizer, StandardScaler
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from sklearn.decomposition import PCA
from sklearn.base import clone

pd.options.display.max_columns = None
sns.set(style='darkgrid')

CLASS = 'class'

def getData():
    train = pd.read_csv('./train.csv')
    test = pd.read_csv('./test.csv')

    X_train, y_train = split_dataset(train, CLASS)
    X_test, y_test = split_dataset(test, CLASS)
    y_train = y_train.map({'pos': 1, 'neg': 0})
    y_test = y_test.map({'pos': 1, 'neg': 0})
    
    return X_train, X_test, y_train, y_test

def getDataWithThresh():
    train = pd.read_csv('./train.csv')
    test = pd.read_csv('./test.csv')

    train = train.dropna(thresh=150)
    train = train.dropna(axis=1, thresh=train.shape[0]*0.9)
    test = test[train.columns]

    X_train, y_train = split_dataset(train, CLASS)
    X_test, y_test = split_dataset(test, CLASS)
    y_train = y_train.map({'pos': 1, 'neg': 0})
    y_test = y_test.map({'pos': 1, 'neg': 0})
    
    return X_train, X_test, y_train, y_test

data = {}

# %%
ks = np.arange(1, 70, 6)
results = {}
res_i = 0
X_train, X_test, y_train, y_test = getData()
X_train, X_test = X_train.fillna(X_train.mean()), X_test.fillna(X_train.mean())

# %%
for k in ks:
    res = aps_classifier_statistics(KNeighborsClassifier(n_neighbors=k), X_train, X_test, y_train, y_test)
    results[res_i] = {'Baseline': res['auc'], 'k': k}
    res_i += 1
    print(res)
# Out:
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9858771929824561, 'confusion_matrix': array([[11140,    63],
#        [   98,    99]]), 'sensibility': 0.5025380710659898, 'specificity': 0.9943765062929573, 'auc': 0.7484572886794736, 'clf': KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=1, p=2,
#            weights='uniform'), 'score': 49630}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9864912280701754, 'confusion_matrix': array([[11170,    33],
#        [  121,    76]]), 'sensibility': 0.38578680203045684, 'specificity': 0.9970543604391681, 'auc': 0.6914205812348125, 'clf': KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=7, p=2,
#            weights='uniform'), 'score': 60830}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9860526315789474, 'confusion_matrix': array([[11181,    22],
#        [  137,    60]]), 'sensibility': 0.30456852791878175, 'specificity': 0.9980362402927787, 'auc': 0.6513023841057802, 'clf': KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=13, p=2,
#            weights='uniform'), 'score': 68720}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.985701754385965, 'confusion_matrix': array([[11182,    21],
#        [  142,    55]]), 'sensibility': 0.27918781725888325, 'specificity': 0.9981255020976524, 'auc': 0.6386566596782679, 'clf': KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=19, p=2,
#            weights='uniform'), 'score': 71210}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9859649122807017, 'confusion_matrix': array([[11186,    17],
#        [  143,    54]]), 'sensibility': 0.27411167512690354, 'specificity': 0.9984825493171472, 'auc': 0.6362971122220253, 'clf': KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=25, p=2,
#            weights='uniform'), 'score': 71670}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9855263157894737, 'confusion_matrix': array([[11186,    17],
#        [  148,    49]]), 'sensibility': 0.24873096446700507, 'specificity': 0.9984825493171472, 'auc': 0.6236067568920761, 'clf': KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=31, p=2,
#            weights='uniform'), 'score': 74170}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9850877192982456, 'confusion_matrix': array([[11185,    18],
#        [  152,    45]]), 'sensibility': 0.22842639593908629, 'specificity': 0.9983932875122735, 'auc': 0.6134098417256798, 'clf': KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=37, p=2,
#            weights='uniform'), 'score': 76180}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9844736842105263, 'confusion_matrix': array([[11184,    19],
#        [  158,    39]]), 'sensibility': 0.19796954314720813, 'specificity': 0.9983040257073998, 'auc': 0.598136784427304, 'clf': KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=43, p=2,
#            weights='uniform'), 'score': 79190}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9841228070175438, 'confusion_matrix': array([[11185,    18],
#        [  163,    34]]), 'sensibility': 0.17258883248730963, 'specificity': 0.9983932875122735, 'auc': 0.5854910599997917, 'clf': KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=49, p=2,
#            weights='uniform'), 'score': 81680}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9840350877192983, 'confusion_matrix': array([[11186,    17],
#        [  165,    32]]), 'sensibility': 0.16243654822335024, 'specificity': 0.9984825493171472, 'auc': 0.5804595487702487, 'clf': KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=55, p=2,
#            weights='uniform'), 'score': 82670}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9844736842105263, 'confusion_matrix': array([[11189,    14],
#        [  163,    34]]), 'sensibility': 0.17258883248730963, 'specificity': 0.9987503347317683, 'auc': 0.585669583609539, 'clf': KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=61, p=2,
#            weights='uniform'), 'score': 81640}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9842105263157894, 'confusion_matrix': array([[11190,    13],
#        [  167,    30]]), 'sensibility': 0.15228426395939088, 'specificity': 0.998839596536642, 'auc': 0.5755619302480165, 'clf': KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=67, p=2,
#            weights='uniform'), 'score': 83630}

# %%
balancers = [(RandomUnderSampler(random_state=42), 'Undersample 50-50'), (RandomUnderSampler(ratio=0.3, random_state=42), 'Undersample 70-30'), (SMOTE(ratio=1.0, random_state=42), 'SMOTE 50-50'), (SMOTE(ratio=0.3, random_state=42), 'SMOTE 70-30')]
filename = 'knn_balancing'
measures = results
i = res_i

for k in ks:

    for balancer, name in balancers:
        X_train_bal, y_train_bal = balancer.fit_sample(X_train, y_train)
        res = aps_classifier_statistics(KNeighborsClassifier(n_neighbors=k), X_train_bal, X_test, y_train_bal, y_test)
        measures[i] = {name: res['auc'], 'k': k, }
        i += 1
        
measures = pd.DataFrame.from_dict(measures, "index")
measures.to_csv('plot_data/{}.csv'.format(filename))

#results[res_i] = {'Price': measures[0]['Price'], 'Transformation': 'Undersampling 70-30'}
#res_i += 1"""
# Out:
# /home/francisconeves/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function _ratio_float is deprecated; Use a float for 'ratio' is deprecated from version 0.2. The support will be removed in 0.4. Use a dict, str, or a callable instead.
#   warnings.warn(msg, category=DeprecationWarning)
# /home/francisconeves/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function _ratio_float is deprecated; Use a float for 'ratio' is deprecated from version 0.2. The support will be removed in 0.4. Use a dict, str, or a callable instead.
#   warnings.warn(msg, category=DeprecationWarning)
# /home/francisconeves/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function _ratio_float is deprecated; Use a float for 'ratio' is deprecated from version 0.2. The support will be removed in 0.4. Use a dict, str, or a callable instead.
#   warnings.warn(msg, category=DeprecationWarning)
# /home/francisconeves/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function _ratio_float is deprecated; Use a float for 'ratio' is deprecated from version 0.2. The support will be removed in 0.4. Use a dict, str, or a callable instead.
#   warnings.warn(msg, category=DeprecationWarning)
# /home/francisconeves/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function _ratio_float is deprecated; Use a float for 'ratio' is deprecated from version 0.2. The support will be removed in 0.4. Use a dict, str, or a callable instead.
#   warnings.warn(msg, category=DeprecationWarning)
# /home/francisconeves/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function _ratio_float is deprecated; Use a float for 'ratio' is deprecated from version 0.2. The support will be removed in 0.4. Use a dict, str, or a callable instead.
#   warnings.warn(msg, category=DeprecationWarning)
# /home/francisconeves/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function _ratio_float is deprecated; Use a float for 'ratio' is deprecated from version 0.2. The support will be removed in 0.4. Use a dict, str, or a callable instead.
#   warnings.warn(msg, category=DeprecationWarning)
# /home/francisconeves/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function _ratio_float is deprecated; Use a float for 'ratio' is deprecated from version 0.2. The support will be removed in 0.4. Use a dict, str, or a callable instead.
#   warnings.warn(msg, category=DeprecationWarning)
# /home/francisconeves/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function _ratio_float is deprecated; Use a float for 'ratio' is deprecated from version 0.2. The support will be removed in 0.4. Use a dict, str, or a callable instead.
#   warnings.warn(msg, category=DeprecationWarning)
# /home/francisconeves/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function _ratio_float is deprecated; Use a float for 'ratio' is deprecated from version 0.2. The support will be removed in 0.4. Use a dict, str, or a callable instead.
#   warnings.warn(msg, category=DeprecationWarning)
# /home/francisconeves/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function _ratio_float is deprecated; Use a float for 'ratio' is deprecated from version 0.2. The support will be removed in 0.4. Use a dict, str, or a callable instead.
#   warnings.warn(msg, category=DeprecationWarning)
# /home/francisconeves/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function _ratio_float is deprecated; Use a float for 'ratio' is deprecated from version 0.2. The support will be removed in 0.4. Use a dict, str, or a callable instead.
#   warnings.warn(msg, category=DeprecationWarning)
# /home/francisconeves/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function _ratio_float is deprecated; Use a float for 'ratio' is deprecated from version 0.2. The support will be removed in 0.4. Use a dict, str, or a callable instead.
#   warnings.warn(msg, category=DeprecationWarning)
# /home/francisconeves/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function _ratio_float is deprecated; Use a float for 'ratio' is deprecated from version 0.2. The support will be removed in 0.4. Use a dict, str, or a callable instead.
#   warnings.warn(msg, category=DeprecationWarning)
# /home/francisconeves/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function _ratio_float is deprecated; Use a float for 'ratio' is deprecated from version 0.2. The support will be removed in 0.4. Use a dict, str, or a callable instead.
#   warnings.warn(msg, category=DeprecationWarning)
# /home/francisconeves/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function _ratio_float is deprecated; Use a float for 'ratio' is deprecated from version 0.2. The support will be removed in 0.4. Use a dict, str, or a callable instead.
#   warnings.warn(msg, category=DeprecationWarning)
# /home/francisconeves/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function _ratio_float is deprecated; Use a float for 'ratio' is deprecated from version 0.2. The support will be removed in 0.4. Use a dict, str, or a callable instead.
#   warnings.warn(msg, category=DeprecationWarning)
# /home/francisconeves/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function _ratio_float is deprecated; Use a float for 'ratio' is deprecated from version 0.2. The support will be removed in 0.4. Use a dict, str, or a callable instead.
#   warnings.warn(msg, category=DeprecationWarning)
# /home/francisconeves/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function _ratio_float is deprecated; Use a float for 'ratio' is deprecated from version 0.2. The support will be removed in 0.4. Use a dict, str, or a callable instead.
#   warnings.warn(msg, category=DeprecationWarning)
# /home/francisconeves/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function _ratio_float is deprecated; Use a float for 'ratio' is deprecated from version 0.2. The support will be removed in 0.4. Use a dict, str, or a callable instead.
#   warnings.warn(msg, category=DeprecationWarning)
# /home/francisconeves/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function _ratio_float is deprecated; Use a float for 'ratio' is deprecated from version 0.2. The support will be removed in 0.4. Use a dict, str, or a callable instead.
#   warnings.warn(msg, category=DeprecationWarning)
# /home/francisconeves/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function _ratio_float is deprecated; Use a float for 'ratio' is deprecated from version 0.2. The support will be removed in 0.4. Use a dict, str, or a callable instead.
#   warnings.warn(msg, category=DeprecationWarning)
# /home/francisconeves/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function _ratio_float is deprecated; Use a float for 'ratio' is deprecated from version 0.2. The support will be removed in 0.4. Use a dict, str, or a callable instead.
#   warnings.warn(msg, category=DeprecationWarning)
# /home/francisconeves/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function _ratio_float is deprecated; Use a float for 'ratio' is deprecated from version 0.2. The support will be removed in 0.4. Use a dict, str, or a callable instead.
#   warnings.warn(msg, category=DeprecationWarning)
# /home/francisconeves/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function _ratio_float is deprecated; Use a float for 'ratio' is deprecated from version 0.2. The support will be removed in 0.4. Use a dict, str, or a callable instead.
#   warnings.warn(msg, category=DeprecationWarning)
# /home/francisconeves/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function _ratio_float is deprecated; Use a float for 'ratio' is deprecated from version 0.2. The support will be removed in 0.4. Use a dict, str, or a callable instead.
#   warnings.warn(msg, category=DeprecationWarning)
# /home/francisconeves/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function _ratio_float is deprecated; Use a float for 'ratio' is deprecated from version 0.2. The support will be removed in 0.4. Use a dict, str, or a callable instead.
#   warnings.warn(msg, category=DeprecationWarning)
# /home/francisconeves/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function _ratio_float is deprecated; Use a float for 'ratio' is deprecated from version 0.2. The support will be removed in 0.4. Use a dict, str, or a callable instead.
#   warnings.warn(msg, category=DeprecationWarning)
# /home/francisconeves/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function _ratio_float is deprecated; Use a float for 'ratio' is deprecated from version 0.2. The support will be removed in 0.4. Use a dict, str, or a callable instead.
#   warnings.warn(msg, category=DeprecationWarning)
# /home/francisconeves/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function _ratio_float is deprecated; Use a float for 'ratio' is deprecated from version 0.2. The support will be removed in 0.4. Use a dict, str, or a callable instead.
#   warnings.warn(msg, category=DeprecationWarning)
# /home/francisconeves/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function _ratio_float is deprecated; Use a float for 'ratio' is deprecated from version 0.2. The support will be removed in 0.4. Use a dict, str, or a callable instead.
#   warnings.warn(msg, category=DeprecationWarning)
# /home/francisconeves/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function _ratio_float is deprecated; Use a float for 'ratio' is deprecated from version 0.2. The support will be removed in 0.4. Use a dict, str, or a callable instead.
#   warnings.warn(msg, category=DeprecationWarning)
# /home/francisconeves/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function _ratio_float is deprecated; Use a float for 'ratio' is deprecated from version 0.2. The support will be removed in 0.4. Use a dict, str, or a callable instead.
#   warnings.warn(msg, category=DeprecationWarning)
# /home/francisconeves/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function _ratio_float is deprecated; Use a float for 'ratio' is deprecated from version 0.2. The support will be removed in 0.4. Use a dict, str, or a callable instead.
#   warnings.warn(msg, category=DeprecationWarning)
# /home/francisconeves/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function _ratio_float is deprecated; Use a float for 'ratio' is deprecated from version 0.2. The support will be removed in 0.4. Use a dict, str, or a callable instead.
#   warnings.warn(msg, category=DeprecationWarning)
# /home/francisconeves/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function _ratio_float is deprecated; Use a float for 'ratio' is deprecated from version 0.2. The support will be removed in 0.4. Use a dict, str, or a callable instead.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
measures = measures.set_index('k')
df = pd.DataFrame()
filename = 'knn_balancing'
for col in measures:
    if col != 'k':
        values = measures[col].dropna()
        if df.empty:
            df = measures[[col]].copy()
        else:
            df = pd.concat([df, values], axis=1, join='inner')
        
df.to_csv('plot_data/{}.csv'.format(filename))

# %%
X_train, X_test, y_train, y_test = getData()
X_train, X_test = X_train.fillna(X_train.mean()), X_test.fillna(X_train.mean())

def balance(X_train, y_train):
    balancer = SMOTE(ratio=1.0, random_state=42)
    return balancer.fit_sample(X_train, y_train)

X_train, y_train = balance(X_train, y_train)

for k in ks:
    res = aps_classifier_statistics(KNeighborsClassifier(n_neighbors=k), X_train, X_test, y_train, y_test)
    results[res_i] = {'SMOTE 50-50': res['score'], 'k': k}
    res_i += 1
    print(res)
# Out:
# /home/francisconeves/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function _ratio_float is deprecated; Use a float for 'ratio' is deprecated from version 0.2. The support will be removed in 0.4. Use a dict, str, or a callable instead.
#   warnings.warn(msg, category=DeprecationWarning)
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9799122807017544, 'confusion_matrix': array([[11034,   169],
#        [   60,   137]]), 'sensibility': 0.6954314720812182, 'specificity': 0.9849147549763456, 'auc': 0.8401731135287819, 'clf': KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=1, p=2,
#            weights='uniform'), 'score': 31690}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9648245614035088, 'confusion_matrix': array([[10833,   370],
#        [   31,   166]]), 'sensibility': 0.8426395939086294, 'specificity': 0.966973132196733, 'auc': 0.9048063630526813, 'clf': KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=7, p=2,
#            weights='uniform'), 'score': 19200}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9594736842105264, 'confusion_matrix': array([[10764,   439],
#        [   23,   174]]), 'sensibility': 0.883248730964467, 'specificity': 0.9608140676604481, 'auc': 0.9220313993124575, 'clf': KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=13, p=2,
#            weights='uniform'), 'score': 15890}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.956140350877193, 'confusion_matrix': array([[10722,   481],
#        [   19,   178]]), 'sensibility': 0.9035532994923858, 'specificity': 0.957065071855753, 'auc': 0.9303091856740694, 'clf': KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=19, p=2,
#            weights='uniform'), 'score': 14310}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9527192982456141, 'confusion_matrix': array([[10682,   521],
#        [   18,   179]]), 'sensibility': 0.9086294416243654, 'specificity': 0.9534945996608052, 'auc': 0.9310620206425854, 'clf': KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=25, p=2,
#            weights='uniform'), 'score': 14210}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9507017543859649, 'confusion_matrix': array([[10657,   546],
#        [   16,   181]]), 'sensibility': 0.9187817258883249, 'specificity': 0.9512630545389628, 'auc': 0.9350223902136438, 'clf': KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=31, p=2,
#            weights='uniform'), 'score': 13460}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9505263157894737, 'confusion_matrix': array([[10655,   548],
#        [   16,   181]]), 'sensibility': 0.9187817258883249, 'specificity': 0.9510845309292154, 'auc': 0.9349331284087702, 'clf': KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=37, p=2,
#            weights='uniform'), 'score': 13480}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9496491228070175, 'confusion_matrix': array([[10645,   558],
#        [   16,   181]]), 'sensibility': 0.9187817258883249, 'specificity': 0.9501919128804784, 'auc': 0.9344868193844016, 'clf': KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=43, p=2,
#            weights='uniform'), 'score': 13580}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9486842105263158, 'confusion_matrix': array([[10633,   570],
#        [   15,   182]]), 'sensibility': 0.9238578680203046, 'specificity': 0.9491207712219941, 'auc': 0.9364893196211492, 'clf': KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=49, p=2,
#            weights='uniform'), 'score': 13200}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9487719298245614, 'confusion_matrix': array([[10634,   569],
#        [   15,   182]]), 'sensibility': 0.9238578680203046, 'specificity': 0.9492100330268678, 'auc': 0.9365339505235861, 'clf': KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=55, p=2,
#            weights='uniform'), 'score': 13190}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9482456140350877, 'confusion_matrix': array([[10628,   575],
#        [   15,   182]]), 'sensibility': 0.9238578680203046, 'specificity': 0.9486744621976256, 'auc': 0.9362661651089651, 'clf': KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=61, p=2,
#            weights='uniform'), 'score': 13250}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9485087719298245, 'confusion_matrix': array([[10632,   571],
#        [   16,   181]]), 'sensibility': 0.9187817258883249, 'specificity': 0.9490315094171204, 'auc': 0.9339066176527226, 'clf': KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=67, p=2,
#            weights='uniform'), 'score': 13710}

# %%
X_train, X_test, y_train, y_test = getData()
X_train, X_test = X_train.fillna(X_train.mean()), X_test.fillna(X_train.mean())

def attribute_corr(df, top):
        
    def get_redundant_pairs(df):
        '''Get diagonal and lower triangular pairs of correlation matrix'''
        pairs_to_drop = set()
        cols = df.columns
        for i in range(0, df.shape[1]):
            for j in range(0, i+1):
                pairs_to_drop.add((cols[i], cols[j]))
        return pairs_to_drop

    def get_top_abs_correlations(df, n=5):
        au_corr = df.corr().abs().unstack()
        labels_to_drop = get_redundant_pairs(df)
        au_corr = au_corr.drop(labels=labels_to_drop).sort_values(ascending=False)
        return au_corr[0:n]

    
    return get_top_abs_correlations(df, top)

correlated_features = attribute_corr(X_train, 7)
correlated_features = correlated_features.reset_index()
print(correlated_features)
# Out:
#   level_0 level_1         0
# 0  bv_000  cq_000  1.000000
# 1  bu_000  cq_000  1.000000
# 2  bu_000  bv_000  1.000000
# 3  ah_000  bg_000  0.999052
# 4  aa_000  bt_000  0.998433
# 5  bb_000  bv_000  0.997017
# 6  bb_000  cq_000  0.997017

# %%
equal_attrs = {}
all_attrs = set([])
sets = 0
for index, corr in correlated_features.iterrows():
    attr1 = corr['level_0']
    attr2 = corr['level_1']
    
    present = False
    if attr1 in equal_attrs:
        equal_attrs[attr1].append(attr1)
    for attr in equal_attrs:
        if attr1 in equal_attrs[attr] or attr2 in equal_attrs[attr]:
            equal_attrs[attr].add(attr1)
            equal_attrs[attr].add(attr2)
            present = True
            
    if not present:
        equal_attrs[sets] = set([attr1, attr2])
        sets += 1
excluded_columns = [item for item in all_attrs if item not in best_attrs]
print('Attribute sets {}'.format(equal_attrs))
# Out:
# Attribute sets {0: {'bu_000', 'cq_000', 'bv_000', 'bb_000'}, 1: {'bg_000', 'ah_000'}, 2: {'bt_000', 'aa_000'}}

# %%
X_train, X_test, y_train, y_test = getData()
X_train, X_test = X_train.fillna(X_train.mean()), X_test.fillna(X_train.mean())

sets = {0: {'bu_000', 'bb_000', 'cq_000', 'bv_000'}, 1: {'bg_000', 'ah_000'}, 2: {'aa_000', 'bt_000'}}

X_train, X_test = X_train.reset_index(drop=True), X_test.reset_index(drop=True)

for group_i in sets:
    group = sets[group_i]
    group_list = list(group)
    group_list.pop(0)
    pca = PCA(n_components=1).fit(X_train[group_list])
    new = pca.transform(X_train[group_list])
    new_test = pca.transform(X_test[group_list])
    
    new = pd.DataFrame(data=new, columns=['{}'.format(group_i)])
    new_test = pd.DataFrame(data=new_test, columns=['{}'.format(group_i)])
    X_train = pd.concat([X_train, new], axis=1)
    X_test = pd.concat([X_test, new_test], axis=1)
    X_train, X_test = X_train.drop(columns=group_list), X_test.drop(columns=group_list)
    
X_train, X_test = X_train.drop(columns=['cd_000']), X_test.drop(columns=['cd_000'])
X_train, y_train = balance(X_train, y_train)
#X_train, X_test = X_train.drop(columns=excluded_columns), X_test.drop(columns=excluded_columns)
# Out:
# /home/francisconeves/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function _ratio_float is deprecated; Use a float for 'ratio' is deprecated from version 0.2. The support will be removed in 0.4. Use a dict, str, or a callable instead.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
for k in ks:
    res = aps_classifier_statistics(KNeighborsClassifier(n_neighbors=k), X_train, X_test, y_train, y_test)
    results[res_i] = {'PCA': res['score'], 'k': k}
    res_i += 1
    print(res)
# Out:
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9799122807017544, 'confusion_matrix': array([[11034,   169],
#        [   60,   137]]), 'sensibility': 0.6954314720812182, 'specificity': 0.9849147549763456, 'auc': 0.8401731135287819, 'clf': KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=1, p=2,
#            weights='uniform'), 'score': 31690}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9647368421052631, 'confusion_matrix': array([[10832,   371],
#        [   31,   166]]), 'sensibility': 0.8426395939086294, 'specificity': 0.9668838703918593, 'auc': 0.9047617321502445, 'clf': KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=7, p=2,
#            weights='uniform'), 'score': 19210}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9592982456140351, 'confusion_matrix': array([[10763,   440],
#        [   24,   173]]), 'sensibility': 0.8781725888324873, 'specificity': 0.9607248058555744, 'auc': 0.9194486973440309, 'clf': KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=13, p=2,
#            weights='uniform'), 'score': 16400}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.956140350877193, 'confusion_matrix': array([[10722,   481],
#        [   19,   178]]), 'sensibility': 0.9035532994923858, 'specificity': 0.957065071855753, 'auc': 0.9303091856740694, 'clf': KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=19, p=2,
#            weights='uniform'), 'score': 14310}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9527192982456141, 'confusion_matrix': array([[10682,   521],
#        [   18,   179]]), 'sensibility': 0.9086294416243654, 'specificity': 0.9534945996608052, 'auc': 0.9310620206425854, 'clf': KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=25, p=2,
#            weights='uniform'), 'score': 14210}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9506140350877192, 'confusion_matrix': array([[10656,   547],
#        [   16,   181]]), 'sensibility': 0.9187817258883249, 'specificity': 0.9511737927340891, 'auc': 0.934977759311207, 'clf': KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=31, p=2,
#            weights='uniform'), 'score': 13470}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9505263157894737, 'confusion_matrix': array([[10655,   548],
#        [   16,   181]]), 'sensibility': 0.9187817258883249, 'specificity': 0.9510845309292154, 'auc': 0.9349331284087702, 'clf': KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=37, p=2,
#            weights='uniform'), 'score': 13480}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9497368421052632, 'confusion_matrix': array([[10646,   557],
#        [   16,   181]]), 'sensibility': 0.9187817258883249, 'specificity': 0.9502811746853521, 'auc': 0.9345314502868385, 'clf': KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=43, p=2,
#            weights='uniform'), 'score': 13570}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9485964912280702, 'confusion_matrix': array([[10632,   571],
#        [   15,   182]]), 'sensibility': 0.9238578680203046, 'specificity': 0.9490315094171204, 'auc': 0.9364446887187124, 'clf': KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=49, p=2,
#            weights='uniform'), 'score': 13210}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9487719298245614, 'confusion_matrix': array([[10634,   569],
#        [   15,   182]]), 'sensibility': 0.9238578680203046, 'specificity': 0.9492100330268678, 'auc': 0.9365339505235861, 'clf': KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=55, p=2,
#            weights='uniform'), 'score': 13190}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9482456140350877, 'confusion_matrix': array([[10628,   575],
#        [   15,   182]]), 'sensibility': 0.9238578680203046, 'specificity': 0.9486744621976256, 'auc': 0.9362661651089651, 'clf': KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=61, p=2,
#            weights='uniform'), 'score': 13250}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9485087719298245, 'confusion_matrix': array([[10632,   571],
#        [   16,   181]]), 'sensibility': 0.9187817258883249, 'specificity': 0.9490315094171204, 'auc': 0.9339066176527226, 'clf': KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=67, p=2,
#            weights='uniform'), 'score': 13710}

# %%
def normalize(X_train, X_test):
    normalizer = Normalizer().fit(X_train)

    X_train_norm = normalizer.transform(X_train)
    X_test_norm = normalizer.transform(X_test)
    
    return X_train_norm, X_test_norm

X_train, X_test, y_train, y_test = getData()
X_train, X_test = X_train.fillna(X_train.mean()), X_test.fillna(X_train.mean())
X_train, y_train = balance(X_train, y_train)
X_train, X_test = normalize(X_train, X_test)
# Out:
# /home/francisconeves/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function _ratio_float is deprecated; Use a float for 'ratio' is deprecated from version 0.2. The support will be removed in 0.4. Use a dict, str, or a callable instead.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
for k in ks:
    res = aps_classifier_statistics(KNeighborsClassifier(n_neighbors=k), X_train, X_test, y_train, y_test)
    results[res_i] = {'Normalization': res['score'], 'k': k}
    res_i += 1
    print(res)
# Out:
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9773684210526316, 'confusion_matrix': array([[11006,   197],
#        [   61,   136]]), 'sensibility': 0.6903553299492385, 'specificity': 0.9824154244398822, 'auc': 0.8363853771945603, 'clf': KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=1, p=2,
#            weights='uniform'), 'score': 32470}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9604385964912281, 'confusion_matrix': array([[10782,   421],
#        [   30,   167]]), 'sensibility': 0.8477157360406091, 'specificity': 0.9624207801481746, 'auc': 0.9050682580943917, 'clf': KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=7, p=2,
#            weights='uniform'), 'score': 19210}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9516666666666667, 'confusion_matrix': array([[10674,   529],
#        [   22,   175]]), 'sensibility': 0.8883248730964467, 'specificity': 0.9527805052218156, 'auc': 0.920552689159131, 'clf': KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=13, p=2,
#            weights='uniform'), 'score': 16290}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9466666666666667, 'confusion_matrix': array([[10616,   587],
#        [   21,   176]]), 'sensibility': 0.8934010152284264, 'specificity': 0.9476033205391413, 'auc': 0.9205021678837838, 'clf': KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=19, p=2,
#            weights='uniform'), 'score': 16370}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9413157894736842, 'confusion_matrix': array([[10554,   649],
#        [   20,   177]]), 'sensibility': 0.8984771573604061, 'specificity': 0.9420690886369723, 'auc': 0.9202731229986892, 'clf': KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=25, p=2,
#            weights='uniform'), 'score': 16490}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9385087719298245, 'confusion_matrix': array([[10520,   683],
#        [   18,   179]]), 'sensibility': 0.9086294416243654, 'specificity': 0.9390341872712666, 'auc': 0.923831814447816, 'clf': KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=31, p=2,
#            weights='uniform'), 'score': 15830}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9355263157894737, 'confusion_matrix': array([[10483,   720],
#        [   15,   182]]), 'sensibility': 0.9238578680203046, 'specificity': 0.9357315004909399, 'auc': 0.9297946842556222, 'clf': KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=37, p=2,
#            weights='uniform'), 'score': 14700}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9329824561403509, 'confusion_matrix': array([[10454,   749],
#        [   15,   182]]), 'sensibility': 0.9238578680203046, 'specificity': 0.9331429081496028, 'auc': 0.9285003880849536, 'clf': KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=43, p=2,
#            weights='uniform'), 'score': 14990}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9312280701754386, 'confusion_matrix': array([[10435,   768],
#        [   16,   181]]), 'sensibility': 0.9187817258883249, 'specificity': 0.9314469338570026, 'auc': 0.9251143298726638, 'clf': KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=49, p=2,
#            weights='uniform'), 'score': 15680}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.93, 'confusion_matrix': array([[10421,   782],
#        [   16,   181]]), 'sensibility': 0.9187817258883249, 'specificity': 0.9301972685887708, 'auc': 0.9244894972385478, 'clf': KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=55, p=2,
#            weights='uniform'), 'score': 15820}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9289473684210526, 'confusion_matrix': array([[10409,   794],
#        [   16,   181]]), 'sensibility': 0.9187817258883249, 'specificity': 0.9291261269302865, 'auc': 0.9239539264093057, 'clf': KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=61, p=2,
#            weights='uniform'), 'score': 15940}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9284210526315789, 'confusion_matrix': array([[10404,   799],
#        [   17,   180]]), 'sensibility': 0.9137055837563451, 'specificity': 0.928679817905918, 'auc': 0.9211927008311317, 'clf': KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=67, p=2,
#            weights='uniform'), 'score': 16490}

# %%
df = pd.DataFrame()
measures = pd.DataFrame.from_dict(results, "index")
results_backup = results

# %%
df = pd.DataFrame()
measures = pd.DataFrame.from_dict(results, "index")
measures = measures.set_index('k')
filename = 'knn_comparison'
for col in measures:
    if col != 'k':
        values = measures[col].dropna()
        if df.empty:
            df = measures[[col]].copy()
        else:
            df = pd.concat([df, values], axis=1, join='inner')
        
df.to_csv('plot_data/{}.csv'.format(filename))
