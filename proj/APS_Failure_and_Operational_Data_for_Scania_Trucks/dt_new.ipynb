# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sys
sys.path.append('..')
from utils_cd import (
        split_dataset,
        standard_deviation,
        plot_comparison_results,
        impute_values,
        plot_results,
        plot_param_improv,
        plot_results_from_csv,
        aps_classifier_statistics,
        aps_score,
)
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB, MultinomialNB, BernoulliNB
from sklearn.decomposition import PCA
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.preprocessing import Normalizer, StandardScaler
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from sklearn.decomposition import PCA
from sklearn.base import clone

pd.options.display.max_columns = None
sns.set(style='darkgrid')

CLASS = 'class'

def getData():
    train = pd.read_csv('./train.csv')
    test = pd.read_csv('./test.csv')

    X_train, y_train = split_dataset(train, CLASS)
    X_test, y_test = split_dataset(test, CLASS)
    y_train = y_train.map({'pos': 1, 'neg': 0})
    y_test = y_test.map({'pos': 1, 'neg': 0})
    
    return X_train, X_test, y_train, y_test

def getDataWithThresh():
    train = pd.read_csv('./train.csv')
    test = pd.read_csv('./test.csv')

    train = train.dropna(thresh=150)
    train = train.dropna(axis=1, thresh=train.shape[0]*0.9)
    test = test[train.columns]

    X_train, y_train = split_dataset(train, CLASS)
    X_test, y_test = split_dataset(test, CLASS)
    y_train = y_train.map({'pos': 1, 'neg': 0})
    y_test = y_test.map({'pos': 1, 'neg': 0})
    
    return X_train, X_test, y_train, y_test

data = {}
clf = DecisionTreeClassifier(random_state=42)
min_samples = np.concatenate([np.arange(5, 51, 5), np.arange(100, 1001, 100)])
num_features = np.arange(10, 170, 3)
results = {}
res_i = 0

# %%
X_train, X_test, y_train, y_test = getDataWithThresh()
X_train, X_test = X_train.fillna(X_train.median()), X_test.fillna(X_train.median())
def balance(X_train, y_train):
    balancer = RandomUnderSampler(ratio=0.3, random_state=42)
    X_train_bal, y_train_bal = balancer.fit_sample(X_train, y_train)
    return X_train_bal, y_train_bal

X_train, y_train = balance(X_train, y_train)
# Out:
# /home/francisconeves/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function _ratio_float is deprecated; Use a float for 'ratio' is deprecated from version 0.2. The support will be removed in 0.4. Use a dict, str, or a callable instead.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
for samples in min_samples:
    res = aps_classifier_statistics(DecisionTreeClassifier(min_samples_split=samples), X_train, X_test, y_train, y_test)
    res_test = aps_classifier_statistics(DecisionTreeClassifier(min_samples_split=samples), X_train, X_train, y_train, y_train)
    results[res_i] = {'Train': res['auc'], 'Min Samples to Split': samples}
    res_i += 1
    results[res_i] = {'Test': res_test['auc'], 'Min Samples to Split': samples}
    res_i += 1
    print(res)
# Out:
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9388596491228071, 'confusion_matrix': array([[10525,   678],
#        [   19,   178]]), 'sensibility': 0.9035532994923858, 'specificity': 0.9394804962956351, 'auc': 0.9215168978940105, 'clf': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=5,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'), 'score': 16280}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9494736842105264, 'confusion_matrix': array([[10645,   558],
#        [   18,   179]]), 'sensibility': 0.9086294416243654, 'specificity': 0.9501919128804784, 'auc': 0.9294106772524219, 'clf': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'), 'score': 14580}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9535964912280702, 'confusion_matrix': array([[10700,   503],
#        [   26,   171]]), 'sensibility': 0.868020304568528, 'specificity': 0.9551013121485317, 'auc': 0.9115608083585298, 'clf': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=15,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'), 'score': 18030}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9517543859649122, 'confusion_matrix': array([[10677,   526],
#        [   24,   173]]), 'sensibility': 0.8781725888324873, 'specificity': 0.9530482906364367, 'auc': 0.9156104397344621, 'clf': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=20,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'), 'score': 17260}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9526315789473684, 'confusion_matrix': array([[10688,   515],
#        [   25,   172]]), 'sensibility': 0.8730964467005076, 'specificity': 0.9540301704900473, 'auc': 0.9135633085952775, 'clf': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=25,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'), 'score': 17650}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9542105263157895, 'confusion_matrix': array([[10705,   498],
#        [   24,   173]]), 'sensibility': 0.8781725888324873, 'specificity': 0.9555476211729002, 'auc': 0.9168601050026938, 'clf': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=30,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'), 'score': 16980}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9547368421052631, 'confusion_matrix': array([[10710,   493],
#        [   23,   174]]), 'sensibility': 0.883248730964467, 'specificity': 0.9559939301972686, 'auc': 0.9196213305808679, 'clf': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=35,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'), 'score': 16430}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9529824561403509, 'confusion_matrix': array([[10690,   513],
#        [   23,   174]]), 'sensibility': 0.883248730964467, 'specificity': 0.9542086940997947, 'auc': 0.9187287125321308, 'clf': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=40,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'), 'score': 16630}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9400877192982456, 'confusion_matrix': array([[10536,   667],
#        [   16,   181]]), 'sensibility': 0.9187817258883249, 'specificity': 0.9404623761492458, 'auc': 0.9296220510187854, 'clf': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=45,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'), 'score': 14670}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9312280701754386, 'confusion_matrix': array([[10435,   768],
#        [   16,   181]]), 'sensibility': 0.9187817258883249, 'specificity': 0.9314469338570026, 'auc': 0.9251143298726638, 'clf': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=50,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'), 'score': 15680}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9417543859649122, 'confusion_matrix': array([[10555,   648],
#        [   16,   181]]), 'sensibility': 0.9187817258883249, 'specificity': 0.9421583504418459, 'auc': 0.9304700381650854, 'clf': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=100,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'), 'score': 14480}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9422807017543859, 'confusion_matrix': array([[10565,   638],
#        [   20,   177]]), 'sensibility': 0.8984771573604061, 'specificity': 0.9430509684905829, 'auc': 0.9207640629254945, 'clf': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=200,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'), 'score': 16380}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9415789473684211, 'confusion_matrix': array([[10550,   653],
#        [   13,   184]]), 'sensibility': 0.934010152284264, 'specificity': 0.9417120414174774, 'auc': 0.9378610968508708, 'clf': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=300,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'), 'score': 13030}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9420175438596491, 'confusion_matrix': array([[10557,   646],
#        [   15,   182]]), 'sensibility': 0.9238578680203046, 'specificity': 0.9423368740515933, 'auc': 0.9330973710359488, 'clf': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=400,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'), 'score': 13960}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9414912280701755, 'confusion_matrix': array([[10549,   654],
#        [   13,   184]]), 'sensibility': 0.934010152284264, 'specificity': 0.9416227796126038, 'auc': 0.9378164659484339, 'clf': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=500,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'), 'score': 13040}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9420175438596491, 'confusion_matrix': array([[10558,   645],
#        [   16,   181]]), 'sensibility': 0.9187817258883249, 'specificity': 0.9424261358564671, 'auc': 0.930603930872396, 'clf': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=600,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'), 'score': 14450}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9419298245614035, 'confusion_matrix': array([[10556,   647],
#        [   15,   182]]), 'sensibility': 0.9238578680203046, 'specificity': 0.9422476122467196, 'auc': 0.933052740133512, 'clf': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=700,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'), 'score': 13970}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9426315789473684, 'confusion_matrix': array([[10565,   638],
#        [   16,   181]]), 'sensibility': 0.9187817258883249, 'specificity': 0.9430509684905829, 'auc': 0.9309163471894539, 'clf': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=800,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'), 'score': 14380}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9439473684210526, 'confusion_matrix': array([[10593,   610],
#        [   29,   168]]), 'sensibility': 0.8527918781725888, 'specificity': 0.9455502990270463, 'auc': 0.8991710885998175, 'clf': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=900,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'), 'score': 20600}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9439473684210526, 'confusion_matrix': array([[10593,   610],
#        [   29,   168]]), 'sensibility': 0.8527918781725888, 'specificity': 0.9455502990270463, 'auc': 0.8991710885998175, 'clf': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=1000,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'), 'score': 20600}
