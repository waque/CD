# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sys
sys.path.append('..')
from utils_cd import (
        split_dataset,
        standard_deviation,
        plot_comparison_results,
        impute_values,
        plot_results,
        plot_param_improv,
        plot_results_from_csv,
        aps_classifier_statistics,
        aps_score,
)
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB, MultinomialNB, BernoulliNB
from sklearn.decomposition import PCA
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.preprocessing import Normalizer, StandardScaler
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from sklearn.decomposition import PCA
from sklearn.base import clone

pd.options.display.max_columns = None
sns.set(style='darkgrid')

CLASS = 'class'

def getData():
    train = pd.read_csv('./train.csv')
    test = pd.read_csv('./test.csv')

    X_train, y_train = split_dataset(train, CLASS)
    X_test, y_test = split_dataset(test, CLASS)
    y_train = y_train.map({'pos': 1, 'neg': 0})
    y_test = y_test.map({'pos': 1, 'neg': 0})
    
    return X_train, X_test, y_train, y_test

def getDataWithThresh():
    train = pd.read_csv('./train.csv')
    test = pd.read_csv('./test.csv')

    train = train.dropna(thresh=150)
    train = train.dropna(axis=1, thresh=train.shape[0]*0.9)
    test = test[train.columns]

    X_train, y_train = split_dataset(train, CLASS)
    X_test, y_test = split_dataset(test, CLASS)
    y_train = y_train.map({'pos': 1, 'neg': 0})
    y_test = y_test.map({'pos': 1, 'neg': 0})
    
    return X_train, X_test, y_train, y_test

data = {}
clf = DecisionTreeClassifier(random_state=42)
min_samples = np.concatenate([np.arange(5, 51, 5), np.arange(100, 1001, 100)])
num_features = np.arange(10, 170, 3)
results = {}
res_i = 0

# %%
X_train, X_test, y_train, y_test = getData()
X_train, X_test = X_train.fillna(X_train.median()), X_test.fillna(X_train.median())
def balance(X_train, y_train):
    balancer = RandomUnderSampler(ratio=0.3, random_state=42)
    X_train_bal, y_train_bal = balancer.fit_sample(X_train, y_train)
    return X_train_bal, y_train_bal

X_train, y_train = balance(X_train, y_train)
# Out:
# /home/francisconeves/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function _ratio_float is deprecated; Use a float for 'ratio' is deprecated from version 0.2. The support will be removed in 0.4. Use a dict, str, or a callable instead.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
for samples in min_samples:
    res = aps_classifier_statistics(DecisionTreeClassifier(min_samples_split=samples), X_train, X_test, y_train, y_test)
    res_train = aps_classifier_statistics(DecisionTreeClassifier(min_samples_split=samples), X_train, X_train, y_train, y_train)
    results[res_i] = {'Test': res['auc'], 'Min Samples to Split': samples}
    res_i += 1
    results[res_i] = {'Train': res_train['auc'], 'Min Samples to Split': samples}
    res_i += 1
    print(res)
    print(res_train)
# Out:
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9642982456140351, 'confusion_matrix': array([[10827,   376],
#        [   31,   166]]), 'sensibility': 0.8426395939086294, 'specificity': 0.9664375613674908, 'auc': 0.9045385776380601, 'clf': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=5,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'), 'score': 19260}
# {'predicted': array([0, 0, 0, ..., 1, 1, 1]), 'accuracy': 0.9967756794104099, 'confusion_matrix': array([[1670,    0],
#        [   7,  494]]), 'sensibility': 0.9860279441117764, 'specificity': 1.0, 'auc': 0.9930139720558881, 'clf': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=5,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'), 'score': 3500}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9654385964912281, 'confusion_matrix': array([[10842,   361],
#        [   33,   164]]), 'sensibility': 0.8324873096446701, 'specificity': 0.9677764884405963, 'auc': 0.9001318990426331, 'clf': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'), 'score': 20110}
# {'predicted': array([0, 0, 0, ..., 1, 1, 1]), 'accuracy': 0.9930907415937356, 'confusion_matrix': array([[1665,    5],
#        [  10,  491]]), 'sensibility': 0.9800399201596807, 'specificity': 0.9970059880239521, 'auc': 0.9885229540918163, 'clf': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'), 'score': 5050}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9633333333333334, 'confusion_matrix': array([[10820,   383],
#        [   35,   162]]), 'sensibility': 0.8223350253807107, 'specificity': 0.965812728733375, 'auc': 0.8940738770570428, 'clf': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=15,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'), 'score': 21330}
# {'predicted': array([0, 0, 0, ..., 1, 1, 1]), 'accuracy': 0.9861814831874712, 'confusion_matrix': array([[1657,   13],
#        [  17,  484]]), 'sensibility': 0.9660678642714571, 'specificity': 0.9922155688622755, 'auc': 0.9791417165668662, 'clf': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=15,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'), 'score': 8630}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9646491228070175, 'confusion_matrix': array([[10839,   364],
#        [   39,   158]]), 'sensibility': 0.8020304568527918, 'specificity': 0.9675087030259751, 'auc': 0.8847695799393834, 'clf': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=20,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'), 'score': 23140}
# {'predicted': array([0, 0, 0, ..., 1, 1, 1]), 'accuracy': 0.9824965453707969, 'confusion_matrix': array([[1655,   15],
#        [  23,  478]]), 'sensibility': 0.9540918163672655, 'specificity': 0.9910179640718563, 'auc': 0.9725548902195609, 'clf': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=20,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'), 'score': 11650}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9629824561403508, 'confusion_matrix': array([[10816,   387],
#        [   35,   162]]), 'sensibility': 0.8223350253807107, 'specificity': 0.9654556815138802, 'auc': 0.8938953534472954, 'clf': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=25,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'), 'score': 21370}
# {'predicted': array([0, 0, 0, ..., 1, 1, 1]), 'accuracy': 0.9774297558728696, 'confusion_matrix': array([[1644,   26],
#        [  23,  478]]), 'sensibility': 0.9540918163672655, 'specificity': 0.9844311377245509, 'auc': 0.9692614770459083, 'clf': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=25,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'), 'score': 11760}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9592982456140351, 'confusion_matrix': array([[10769,   434],
#        [   30,   167]]), 'sensibility': 0.8477157360406091, 'specificity': 0.9612603766848166, 'auc': 0.9044880563627128, 'clf': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=30,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'), 'score': 19340}
# {'predicted': array([0, 1, 0, ..., 1, 1, 1]), 'accuracy': 0.9705204974666053, 'confusion_matrix': array([[1626,   44],
#        [  20,  481]]), 'sensibility': 0.9600798403193613, 'specificity': 0.9736526946107784, 'auc': 0.9668662674650699, 'clf': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=30,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'), 'score': 10440}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9592105263157895, 'confusion_matrix': array([[10768,   435],
#        [   30,   167]]), 'sensibility': 0.8477157360406091, 'specificity': 0.9611711148799429, 'auc': 0.904443425460276, 'clf': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=35,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'), 'score': 19350}
# {'predicted': array([0, 1, 0, ..., 1, 1, 1]), 'accuracy': 0.9695992630124367, 'confusion_matrix': array([[1624,   46],
#        [  20,  481]]), 'sensibility': 0.9600798403193613, 'specificity': 0.9724550898203593, 'auc': 0.9662674650698604, 'clf': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=35,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'), 'score': 10460}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9625438596491228, 'confusion_matrix': array([[10804,   399],
#        [   28,   169]]), 'sensibility': 0.8578680203045685, 'specificity': 0.9643845398553959, 'auc': 0.9111262800799821, 'clf': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=40,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'), 'score': 17990}
# {'predicted': array([0, 1, 0, ..., 1, 1, 1]), 'accuracy': 0.966835559649931, 'confusion_matrix': array([[1626,   44],
#        [  28,  473]]), 'sensibility': 0.9441117764471058, 'specificity': 0.9736526946107784, 'auc': 0.958882235528942, 'clf': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=40,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'), 'score': 14440}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9627192982456141, 'confusion_matrix': array([[10806,   397],
#        [   28,   169]]), 'sensibility': 0.8578680203045685, 'specificity': 0.9645630634651433, 'auc': 0.911215541884856, 'clf': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=45,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'), 'score': 17970}
# {'predicted': array([0, 1, 0, ..., 1, 1, 1]), 'accuracy': 0.966835559649931, 'confusion_matrix': array([[1626,   44],
#        [  28,  473]]), 'sensibility': 0.9441117764471058, 'specificity': 0.9736526946107784, 'auc': 0.958882235528942, 'clf': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=45,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'), 'score': 14440}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9628947368421052, 'confusion_matrix': array([[10808,   395],
#        [   28,   169]]), 'sensibility': 0.8578680203045685, 'specificity': 0.9647415870748907, 'auc': 0.9113048036897295, 'clf': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=50,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'), 'score': 17950}
# {'predicted': array([0, 1, 0, ..., 1, 1, 1]), 'accuracy': 0.9663749424228466, 'confusion_matrix': array([[1626,   44],
#        [  29,  472]]), 'sensibility': 0.9421157684630739, 'specificity': 0.9736526946107784, 'auc': 0.9578842315369261, 'clf': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=50,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'), 'score': 14940}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9492105263157895, 'confusion_matrix': array([[10635,   568],
#        [   11,   186]]), 'sensibility': 0.9441624365482234, 'specificity': 0.9492992948317415, 'auc': 0.9467308656899823, 'clf': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=100,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'), 'score': 11180}
# {'predicted': array([0, 1, 0, ..., 1, 1, 1]), 'accuracy': 0.9567019806540764, 'confusion_matrix': array([[1587,   83],
#        [  11,  490]]), 'sensibility': 0.9780439121756487, 'specificity': 0.9502994011976048, 'auc': 0.9641716566866267, 'clf': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=100,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'), 'score': 6330}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9494736842105264, 'confusion_matrix': array([[10638,   565],
#        [   11,   186]]), 'sensibility': 0.9441624365482234, 'specificity': 0.9495670802463626, 'auc': 0.946864758397293, 'clf': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=200,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'), 'score': 11150}
# {'predicted': array([0, 1, 0, ..., 1, 1, 1]), 'accuracy': 0.9567019806540764, 'confusion_matrix': array([[1587,   83],
#        [  11,  490]]), 'sensibility': 0.9780439121756487, 'specificity': 0.9502994011976048, 'auc': 0.9641716566866267, 'clf': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=200,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'), 'score': 6330}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9492105263157895, 'confusion_matrix': array([[10635,   568],
#        [   11,   186]]), 'sensibility': 0.9441624365482234, 'specificity': 0.9492992948317415, 'auc': 0.9467308656899823, 'clf': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=300,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'), 'score': 11180}
# {'predicted': array([0, 1, 0, ..., 1, 1, 1]), 'accuracy': 0.9567019806540764, 'confusion_matrix': array([[1587,   83],
#        [  11,  490]]), 'sensibility': 0.9780439121756487, 'specificity': 0.9502994011976048, 'auc': 0.9641716566866267, 'clf': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=300,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'), 'score': 6330}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9492105263157895, 'confusion_matrix': array([[10634,   569],
#        [   10,   187]]), 'sensibility': 0.949238578680203, 'specificity': 0.9492100330268678, 'auc': 0.9492243058535355, 'clf': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=400,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'), 'score': 10690}
# {'predicted': array([0, 1, 0, ..., 1, 1, 1]), 'accuracy': 0.9557807461999078, 'confusion_matrix': array([[1585,   85],
#        [  11,  490]]), 'sensibility': 0.9780439121756487, 'specificity': 0.9491017964071856, 'auc': 0.9635728542914171, 'clf': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=400,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'), 'score': 6350}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9490350877192982, 'confusion_matrix': array([[10632,   571],
#        [   10,   187]]), 'sensibility': 0.949238578680203, 'specificity': 0.9490315094171204, 'auc': 0.9491350440486618, 'clf': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=500,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'), 'score': 10710}
# {'predicted': array([0, 1, 0, ..., 1, 1, 1]), 'accuracy': 0.9557807461999078, 'confusion_matrix': array([[1585,   85],
#        [  11,  490]]), 'sensibility': 0.9780439121756487, 'specificity': 0.9491017964071856, 'auc': 0.9635728542914171, 'clf': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=500,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'), 'score': 6350}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9492105263157895, 'confusion_matrix': array([[10634,   569],
#        [   10,   187]]), 'sensibility': 0.949238578680203, 'specificity': 0.9492100330268678, 'auc': 0.9492243058535355, 'clf': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=600,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'), 'score': 10690}
# {'predicted': array([0, 1, 0, ..., 1, 1, 1]), 'accuracy': 0.9557807461999078, 'confusion_matrix': array([[1585,   85],
#        [  11,  490]]), 'sensibility': 0.9780439121756487, 'specificity': 0.9491017964071856, 'auc': 0.9635728542914171, 'clf': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=600,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'), 'score': 6350}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9492105263157895, 'confusion_matrix': array([[10634,   569],
#        [   10,   187]]), 'sensibility': 0.949238578680203, 'specificity': 0.9492100330268678, 'auc': 0.9492243058535355, 'clf': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=700,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'), 'score': 10690}
# {'predicted': array([0, 1, 0, ..., 1, 1, 1]), 'accuracy': 0.9557807461999078, 'confusion_matrix': array([[1585,   85],
#        [  11,  490]]), 'sensibility': 0.9780439121756487, 'specificity': 0.9491017964071856, 'auc': 0.9635728542914171, 'clf': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=700,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'), 'score': 6350}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9492105263157895, 'confusion_matrix': array([[10634,   569],
#        [   10,   187]]), 'sensibility': 0.949238578680203, 'specificity': 0.9492100330268678, 'auc': 0.9492243058535355, 'clf': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=800,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'), 'score': 10690}
# {'predicted': array([0, 1, 0, ..., 1, 1, 1]), 'accuracy': 0.9557807461999078, 'confusion_matrix': array([[1585,   85],
#        [  11,  490]]), 'sensibility': 0.9780439121756487, 'specificity': 0.9491017964071856, 'auc': 0.9635728542914171, 'clf': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=800,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'), 'score': 6350}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9490350877192982, 'confusion_matrix': array([[10632,   571],
#        [   10,   187]]), 'sensibility': 0.949238578680203, 'specificity': 0.9490315094171204, 'auc': 0.9491350440486618, 'clf': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=900,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'), 'score': 10710}
# {'predicted': array([0, 1, 0, ..., 1, 1, 1]), 'accuracy': 0.9557807461999078, 'confusion_matrix': array([[1585,   85],
#        [  11,  490]]), 'sensibility': 0.9780439121756487, 'specificity': 0.9491017964071856, 'auc': 0.9635728542914171, 'clf': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=900,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'), 'score': 6350}
# {'predicted': array([0, 0, 0, ..., 0, 0, 0]), 'accuracy': 0.9490350877192982, 'confusion_matrix': array([[10632,   571],
#        [   10,   187]]), 'sensibility': 0.949238578680203, 'specificity': 0.9490315094171204, 'auc': 0.9491350440486618, 'clf': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=1000,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'), 'score': 10710}
# {'predicted': array([0, 1, 0, ..., 1, 1, 1]), 'accuracy': 0.9557807461999078, 'confusion_matrix': array([[1585,   85],
#        [  11,  490]]), 'sensibility': 0.9780439121756487, 'specificity': 0.9491017964071856, 'auc': 0.9635728542914171, 'clf': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=1000,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'), 'score': 6350}

# %%
measures = pd.DataFrame.from_dict(results, "index")
measures = measures.set_index('Min Samples to Split')
filename = 'dt_min_samples'
df = pd.DataFrame()
for col in measures:
    if col != 'Min Samples to Split':
        values = measures[col].dropna()
        if df.empty:
            df = measures[[col]].copy()
        else:
            df = pd.concat([df, values], axis=1, join='inner')
        
df.to_csv('plot_data/{}.csv'.format(filename))
